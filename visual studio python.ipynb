# %%
len(range(0,10))
# Out:
# 10

# %%
a = range(0,10)

# %%
a
# Out:
# range(0, 10)

# %%
class Circle:
    def __init__(self,radius):
        self.__radius = radius
    @property
    def radius(self):
        return self.__radius
    @radius.setter
    def radius(self,value):
        if value <= 0:
            raise valueError("Radius is no pos")
        self.__radius = value
    def area(self):
        return 3.14 * self__radius * self.__radius

# %%
d = Circle(10)

# %%
d.radius
# Out:
# 10

# %%
d.radius = 5

# %%
d.radius = -1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d.radius = -1
#
# NameError: name 'd' is not defined

# %%
file = open("file.txt","w")

# %%
file.write("hello this is my first line")
# Out:
# 27
