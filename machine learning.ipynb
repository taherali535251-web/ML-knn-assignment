# %%
import numpy as np
import pandas as pd

# %%
data = {
    'A':[1,2,100,4,5],
    'B':[3,np.nan,7,8,9],
    'C':[np.nan,12,13,14,15],
    'D':[16,17,18,np.nan,20]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B     C     D
# 0    1  3.0   NaN  16.0
# 1    2  NaN  12.0  17.0
# 2  100  7.0  13.0  18.0
# 3    4  8.0  14.0   NaN
# 4    5  9.0  15.0  20.0

# %%
df.isnull().sum()
# Out:
# A    1
# B    1
# C    1
# D    1
# dtype: int64

# %%
df.dropna()
# Out:
#      A    B     C     D
# 2  100  7.0  13.0  18.0
# 4    5  9.0  15.0  20.0

# %%
df.dropna(axis =1)
# Out:
#      A
# 0    1
# 1    2
# 2  100
# 3    4
# 4    5

# %%
df['B']
# Out:
# 0    3.0
# 1    NaN
# 2    7.0
# 3    8.0
# 4    9.0
# Name: B, dtype: float64

# %%
df['B'].fillna(df['B'].mean())
# Out:
# 0    3.00
# 1    6.75
# 2    7.00
# 3    8.00
# 4    9.00
# Name: B, dtype: float64

# %%
df['B'].mean()
# Out:
# np.float64(6.75)

# %%
df['C'].fillna(0)
# Out:
# 0     0.0
# 1    12.0
# 2    13.0
# 3    14.0
# 4    15.0
# Name: C, dtype: float64

# %%
df['C'].median()
# Out:
# 13.5

# %%
df['C'].fillna(df['C'].mean())
# Out:
# 0    13.5
# 1    12.0
# 2    13.0
# 3    14.0
# 4    15.0
# Name: C, dtype: float64

# %%
df['C']=df['C'].fillna(df['C'].mean())

# %%
df
# Out:
#      A    B     C     D
# 0    1  3.0  13.5  16.0
# 1    2  NaN  12.0  17.0
# 2  100  7.0  13.0  18.0
# 3    4  8.0  14.0   NaN
# 4    5  9.0  15.0  20.0

# %%
import seaborn as sns

# %%
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1 =df.dropna(axis =1)

# %%
#imputation of missing values

# %%
sns.histplot(df.age,kde = True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df1
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %%
#whenever we have normal distribution data, impute with mean

# %%
df['mean_imputation']=df['age'].fillna(df['age'].mean())

# %%
df[['age','mean_imputation']]
# Out:
#       age  mean_imputation
# 0    22.0        22.000000
# 1    38.0        38.000000
# 2    26.0        26.000000
# 3    35.0        35.000000
# 4    35.0        35.000000
# ..    ...              ...
# 886  27.0        27.000000
# 887  19.0        19.000000
# 888   NaN        29.699118
# 889  26.0        26.000000
# 890  32.0        32.000000
#
# [891 rows x 2 columns]

# %%
sns.distplot(df['mean_imputation'],kde = True)
# Out:
# C:\Users\TAHERALI\AppData\Local\Temp\ipykernel_2312\3990486819.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['mean_imputation'],kde = True)
# <Axes: xlabel='mean_imputation', ylabel='Density'>

# %%
#mean imputatio works well with normally distribution data when no outloer is present

# %%
df['median_imputation']=df['age'].fillna(df['age'].median())

# %%
df[['age','median_imputation','mean_imputation']]
# Out:
#       age  median_imputation  mean_imputation
# 0    22.0               22.0        22.000000
# 1    38.0               38.0        38.000000
# 2    26.0               26.0        26.000000
# 3    35.0               35.0        35.000000
# 4    35.0               35.0        35.000000
# ..    ...                ...              ...
# 886  27.0               27.0        27.000000
# 887  19.0               19.0        19.000000
# 888   NaN               28.0        29.699118
# 889  26.0               26.0        26.000000
# 890  32.0               32.0        32.000000
#
# [891 rows x 3 columns]

# %%
#imputation with mode in categorical data

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone', 'mean_imputation', 'median_imputation'],
#       dtype='object')

# %%
df[df['embarked'].isnull()] # it is a random null
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked  class  \
# 61          1       1  female  38.0      0      0  80.0      NaN  First
# 829         1       1  female  62.0      0      0  80.0      NaN  First
#
#        who  adult_male deck embark_town alive  alone  mean_imputation  \
# 61   woman       False    B         NaN   yes   True             38.0
# 829  woman       False    B         NaN   yes   True             62.0
#
#      median_imputation
# 61                38.0
# 829               62.0

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.notna().sum()
# Out:
# survived             891
# pclass               891
# sex                  891
# age                  714
# sibsp                891
# parch                891
# fare                 891
# embarked             889
# class                891
# who                  891
# adult_male           891
# deck                 203
# embark_town          889
# alive                891
# alone                891
# mean_imputation      891
# median_imputation    891
# dtype: int64

# %%
df[df['embarked'].notna()]['embarked'].mode()
# Out:
# 0    S
# Name: embarked, dtype: object

# %%
em_mode=df[df['embarked'].notna()]['embarked'].mode()[0]

# %%
df['update_embar']=df['embarked'].fillna(em_mode)

# %%
df[['update_embar','embarked']]
# Out:
#     update_embar embarked
# 0              S        S
# 1              C        C
# 2              S        S
# 3              S        S
# 4              S        S
# ..           ...      ...
# 886            S        S
# 887            S        S
# 888            S        S
# 889            C        C
# 890            Q        Q
#
# [891 rows x 2 columns]

# %%
df['update_embar'].isnull().sum()
# Out:
# np.int64(0)
