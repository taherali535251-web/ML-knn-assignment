# %%
pip install bokeh
# Out:
# Requirement already satisfied: bokeh in c:\users\taherali\anaconda3\lib\site-packages (3.6.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (2.1.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (24.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (2.2.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (11.1.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\taherali\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taherali\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\taherali\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\taherali\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\taherali\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="ad689189-e064-4f98-9bd2-4f32f3a17020">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.plotting import figure , output_file , show

# %%
pip install bokeh_sampledata
# Out:
# Collecting bokeh_sampledata
#   Downloading bokeh_sampledata-2025.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting icalendar (from bokeh_sampledata)
#   Downloading icalendar-6.3.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pandas>=1.2 in c:\users\taherali\anaconda3\lib\site-packages (from bokeh_sampledata) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\taherali\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\taherali\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\taherali\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\taherali\anaconda3\lib\site-packages (from pandas>=1.2->bokeh_sampledata) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\taherali\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh_sampledata) (1.17.0)
# Downloading bokeh_sampledata-2025.0-py3-none-any.whl (17.7 MB)
#    ---------------------------------------- 0.0/17.7 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/17.7 MB 8.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.6/17.7 MB 6.6 MB/s eta 0:00:03
#    ------ --------------------------------- 2.9/17.7 MB 6.1 MB/s eta 0:00:03
#    ------- -------------------------------- 3.4/17.7 MB 4.0 MB/s eta 0:00:04
#    -------- ------------------------------- 3.7/17.7 MB 3.6 MB/s eta 0:00:04
#    -------- ------------------------------- 3.7/17.7 MB 3.6 MB/s eta 0:00:04
#    --------- ------------------------------ 4.2/17.7 MB 3.0 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.5/17.7 MB 2.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.5/17.7 MB 2.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.7/17.7 MB 2.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.0/17.7 MB 2.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.0/17.7 MB 2.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.0/17.7 MB 2.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 5.2/17.7 MB 1.7 MB/s eta 0:00:08
#    ------------- -------------------------- 6.0/17.7 MB 1.9 MB/s eta 0:00:07
#    -------------- ------------------------- 6.3/17.7 MB 1.9 MB/s eta 0:00:06
#    --------------- ------------------------ 6.8/17.7 MB 1.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 7.3/17.7 MB 1.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 7.3/17.7 MB 1.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 7.6/17.7 MB 1.8 MB/s eta 0:00:06
#    ----------------- ---------------------- 7.6/17.7 MB 1.8 MB/s eta 0:00:06
#    ------------------ --------------------- 8.1/17.7 MB 1.7 MB/s eta 0:00:06
#    ------------------ --------------------- 8.4/17.7 MB 1.8 MB/s eta 0:00:06
#    -------------------- ------------------- 9.2/17.7 MB 1.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 10.2/17.7 MB 1.9 MB/s eta 0:00:04
#    -------------------------- ------------- 11.5/17.7 MB 2.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 12.6/17.7 MB 2.2 MB/s eta 0:00:03
#    ------------------------------ --------- 13.6/17.7 MB 2.3 MB/s eta 0:00:02
#    -------------------------------- ------- 14.4/17.7 MB 2.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 15.7/17.7 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 16.5/17.7 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 17.0/17.7 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  17.6/17.7 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 17.7/17.7 MB 2.5 MB/s eta 0:00:00
# Downloading icalendar-6.3.2-py3-none-any.whl (242 kB)
# Installing collected packages: icalendar, bokeh_sampledata
#
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    ---------------------------------------- 0/2 [icalendar]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    -------------------- ------------------- 1/2 [bokeh_sampledata]
#    ---------------------------------------- 2/2 [bokeh_sampledata]
#
# Successfully installed bokeh_sampledata-2025.0 icalendar-6.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
output_file('test.html')
p = figure (title = 'test_flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="b92f56eb-ccfd-4ba0-8fb3-186cbaf2c49a" data-root-id="p1276" style="display: contents;"></div>

# %%
output_file('test.html')
p = figure (title = 'test_flower')
p.xaxis.axis_label = 'petal_length'
p.yaxis.axis_label = 'petal_width'
p.line(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
#   <div id="f0a69a43-e87c-4bd4-a4f2-b59564210c30" data-root-id="p1145" style="display: contents;"></div>

# %%
x = [1,2,3,4] 
y =[3,8,4,7]

output_file('line.html')
p = figure(title = 'line chat')
p.line(x,y)
show(p)
# Out:
#   <div id="a32535a1-78d7-4e89-9a67-4b10bcc7e14f" data-root-id="p1324" style="display: contents;"></div>

# %%
x = [1,2,3,4] 
y =[3,8,4,7]

output_file('line.html')
p = figure(title = 'line chat')
p.scatter(x,y)
show(p)
# Out:
#   <div id="ad8be6ea-395e-400f-924b-f91a49425c63" data-root-id="p1368" style="display: contents;"></div>

# %%
x = [1,2,3,4] 
y =[3,8,4,7]

output_file('line.html')
p = figure(title = 'line chat')
p.scatter(x,y,size = 20, fill_color = 'red',legend_label= 'this is Bkokeh')
show(p)
# Out:
#   <div id="c437c3b9-6291-4838-b4b5-1b05fb01b46a" data-root-id="p1412" style="display: contents;"></div>
