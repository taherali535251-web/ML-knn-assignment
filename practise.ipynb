# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(483)

# %%
df.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy = df.copy()
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.reset_index(drop = True, inplace=True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy =df_copy.drop_duplicates()

# %%
df_copy.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_copy[~df_copy['Reviews'].str.isnumeric()]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df_copy =df_copy.drop(df_copy.index[9990])

# %%
df_copy['Reviews']=df_copy['Reviews'].astype(int)

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
def size_pro(item):
    if str(item)[-1] == "M":
        res = float(str(item).replace('M',''))
        res = res*1024
        return res
    elif str(item)[-1]=='K':
        res = float(str(item).replace('K',''))
        return res
    else:
        return str(np.nan)

# %%
df_copy['Size'] = df['Size'].apply(size_pro)

# %%
df_copy['Size'] = df_copy['Size'].astype(float)

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df_copy['Installs'] = df['Installs'].str.replace('+','').str.replace(',','')

# %%
df_copy['Installs'] = df_copy['Installs'].astype(int)

# %%
df_copy['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
df_copy['Price']= df_copy['Price'].str.replace('$','').str.replace(',','')

# %%
df_copy['Price'] =df_copy['Price'].astype(float)

# %%
df_copy['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df_copy['Last Updated'] =pd.to_datetime(df_copy['Last Updated'])

# %%
df_copy.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                    int64
# Size                     float64
# Installs                   int64
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# dtype: object

# %%
df_copy['year']=df_copy['Last Updated'].dt.year
df_copy['month']=df_copy['Last Updated'].dt.month
df_copy['day']=df_copy['Last Updated'].dt.day

# %%
df_copy = df_copy.drop('Last Updated', axis =1)

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size              float64
# Installs            int64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Current Ver        object
# Android Ver        object
# year                int32
# month               int32
# day                 int32
# dtype: object

# %%
df_copy['Android Ver']=df_copy['Android Ver'].str.replace("and up","").str.replace("Varies with device","")

# %%
df_copy['App'].duplicated().sum()
# Out:
# np.int64(698)

# %%
df_copy = df_copy.drop_duplicates(subset=['App'],keep='first')

# %%
categorical_fet = [feature for feature in df_copy.columns if df_copy[feature].dtypes == 'O']

# %%
categorical_fet
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
numerical_fet
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'year', 'month', 'day']

# %%
numerical_fet = [feature for feature in df_copy.columns if df_copy[feature].dtypes != 'O']

# %%
numerical_fet
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'year', 'month', 'day']

# %%
df['Type'].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.610701
# Paid     7.380074
# 0        0.009225
# Name: proportion, dtype: float64

# %%
sns.countplot(x =df_copy['Content Rating'])
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
df_copy['Category'].value_counts().plot.pie(y =df_copy['Category'], figsize=(12,12), autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
a =df_copy['Category'].value_counts()[:10]

# %%
category = a.reset_index()

# %%
category.columns = ['Groups','countsis']

# %%
sns.barplot(category, x = category['Groups'],y =category['countsis'])
# Out:
# <Axes: xlabel='Groups', ylabel='countsis'>

# %%
b =df_copy.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=b, x="Category", y="Installs")
plt.xticks(rotation=45)
plt.title("Total Installs and Category")
plt.show()

# %%
sns.boxplot(x ="Installs", y="Rating", data =df_copy)
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>

# %%
sns.boxplot(df_copy, x=df_copy['Installs'], y=df_copy['year'])
# Out:
# <Axes: xlabel='Installs', ylabel='year'>

# %%
b =df_copy.groupby(["Category", "Type"])["Installs"].sum().reset_index()

# %%
c =df_copy.groupby(['Category','Type'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=c, x="Category", y="Installs", hue="Type")
plt.xticks(rotation=45)
plt.title("Total Installs by Category and Type")
plt.show()

# %%
a =df_copy.groupby(['Category','App'])['Reviews'].sum().sort_values(ascending=False).reset_index()

# %%
a
# Out:
#                 Category                                       App   Reviews
# 0                 SOCIAL                                  Facebook  78158306
# 1          COMMUNICATION                        WhatsApp Messenger  69119316
# 2                 SOCIAL                                 Instagram  66577313
# 3          COMMUNICATION  Messenger – Text and Video Chat for Free  56642847
# 4                   GAME                            Clash of Clans  44891723
# ...                  ...                                       ...       ...
# 9654            BUSINESS                      Bk Bee Sales Manager         0
# 9655            BUSINESS                        Border Ag & Energy         0
# 9656           LIFESTYLE                      Freedom Christian BF         0
# 9657  HEALTH_AND_FITNESS                             D.W Bien Être         0
# 9658            BUSINESS                            BV Productions         0
#
# [9659 rows x 3 columns]

# %%
a =df_copy.groupby(['Category'])['Size'].sum().sort_values(ascending=False).reset_index()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=a, x="Category", y="Size")
plt.xticks(rotation=45)
plt.title("Total Installs by Category and Type")
plt.show()

# %%
sns.boxplot(df_copy['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.boxplot(x ="Installs", y="Rating", data =df_copy)
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>
