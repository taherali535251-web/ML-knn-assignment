# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host='localhost',user='root',passwd="Tah786110$")

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('pwskillsmysql',),
#  ('pysqldb',),
#  ('sys',),
#  ('taher',)]

# %%
cursor.execute("create database pysqldb")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\TAHERALI\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Can't create database 'pysqldb'; database exists
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 cursor.execute("create database pysqldb")
#
# ...

# %%
cursor.execute("create table pysqldb.pwskills(studentid INT(10),firstname VARCHAR(30), lastname VARCHAR(30),regid INT(30), classname VARCHAR(30))")

# %%
cursor.execute('use pysqldb')

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('pwskills',)]

# %%
cursor.execute("insert into pysqldb.pwskills values(45,'Taher','sahil',34,'fsds')")

# %%
mydb.commit()

# %%
cursor.execute('select * from pysqldb.pwskills')

# %%
cursor.fetchall()
# Out:
# [(45, 'Taher', 'sahil', 34, 'fsds')]

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 9262-288D
#
#  Directory of c:\Users\TAHERALI\Downloads
#
# 12-01-2026  21:17    <DIR>          .
# 10-01-2026  21:03    <DIR>          ..
# 28-11-2025  08:04       958,742,216 Anaconda3-2025.06-0-Windows-x86_64.exe
# 08-01-2026  22:00            65,854 Bokeh.ipynb
# 28-12-2025  13:15            10,815 class and static method.ipynb
# 28-12-2025  14:40             8,463 decorators (1).ipynb
# 20-12-2025  22:09            31,921 dictionary.ipynb
# 22-12-2025  22:48                 0 file.txt
# 13-12-2025  00:50            33,574 functions.ipynb
# 12-01-2026  20:21             2,052 learn mysql2.sql
# 13-12-2025  19:41            56,689 List.ipynb
# 28-11-2025  04:45         1,106,976 Microsoft 365 Copilot Installer (1).exe
# 10-01-2026  22:04       585,392,128 mysql-installer-community-8.0.44.0.msi
# 03-01-2026  21:38           228,170 pandas_advance_1.ipynb
# 07-01-2026  20:04           224,310 pandas_advance-2 (1).ipynb
# ...

# %%
cursor.execute('create table pysqldb.glassdata(col1 INT(10) ,col2 float(10,5),col3 float(10,5) ,col4 float(10,5) , col5 float(10,5),col6 float(10,5) ,clo7 float(10,5) , col8 float(10,5) , col9 float(10,5) , col10 float(10,5) , col11 INT(10)) ')

# %%
cursor.execute('insert into pysqldb.glassdata values(1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1)')

# %%
mydb.commit()

# %%
import csv
with open('glass.data','r') as f:
    glass_data=csv.reader(f,delimiter=',')
    for i in glass_data:
        print(type(i[0]))
        print(f'insert into glassdata values ({str(i[0])})')
        cursor.execute('insert into pysqldb.glassdata values({values})'.format(values = ((i[0]))))
# Out:
# <class 'str'>
# insert into glassdata values (1)
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\TAHERALI\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Column count doesn't match value count at row 1
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       5 print(type(i[0]))
# ...

# %%
glass_data

# %%
import pandas as pd

# %%
pd.read_sql('select * from pysqldb.pwskills',mydb)
# Out:
# C:\Users\TAHERALI\AppData\Local\Temp\ipykernel_23044\3652025134.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('select * from pysqldb.pwskills',mydb)
#    studentid firstname lastname  regid classname
# 0         45     Taher    sahil     34      fsds

# %%
pd.read_sql('show databases', mydb)
# Out:
# C:\Users\TAHERALI\AppData\Local\Temp\ipykernel_23044\3468230276.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql('show databases', mydb)
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3       pwskillsmysql
# 4             pysqldb
# 5                 sys
# 6               taher

# %%
pip install "pymongo[srv]==3.12"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://taherali535251_db_user:Tah786110@cluster0.eobina9.mongodb.net/?appName=Cluster0")

# %%
client
# Out:
# MongoClient(host=['ac-dyhukzt-shard-00-02.eobina9.mongodb.net:27017', 'ac-dyhukzt-shard-00-01.eobina9.mongodb.net:27017', 'ac-dyhukzt-shard-00-00.eobina9.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, appname='Cluster0', authsource='admin', replicaset='atlas-8j37j5-shard-0', ssl=True)

# %%
db = client["pwskills"]

# %%
coll_create = db["my_record"]

# %%
data = {"name":"Taher",
        "class":"Dataanalyst stud",
        "timing":"flexi"
        }

# %%
coll_create.insert_one(data)

# %%
data2 = {"list_course":["data analytisc","java","python",],
         "mentor":["Rajiv","Imran","Ajay"]}

# %%
coll_create.insert_one(data2)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('69665d0e3ed2332a724e8b61'), 'name': 'Taher', 'class': 'Dataanalyst stud', 'timing': 'flexi'}
# {'_id': ObjectId('69665fb73ed2332a724e8b63'), 'name': 'Taher', 'class': 'Dataanalyst stud', 'timing': 'flexi'}
# {'_id': ObjectId('6966602d3ed2332a724e8b64'), 'list_course': ['data analytisc', 'java', 'python'], 'mentor': ['Rajiv', 'Imran', 'Ajay']}

# %%
data3 = [
  { "name": "Amy", "address": "Apple st 652" },
  { "name": "Hannah", "address": "Mountain 21" },
  { "name": "Michael", "address": "Valley 345" },
  { "name": "Sandy", "address": "Ocean blvd 2" },
  { "name": "Betty", "address": "Green Grass 1" },
  { "name": "Richard", "address": "Sky st 331" },
  { "name": "Susan", "address": "One way 98" },
  { "name": "Vicky", "address": "Yellow Garden 2" },
  { "name": "Ben", "address": "Park Lane 38" },
  { "name": "William", "address": "Central st 954" },
  { "name": "Chuck", "address": "Main Road 989" },
  { "name": "Viola", "address": "Sideway 1633" }
]

# %%
coll_create.insert_many(data3)

# %%
data4 =list_of_records = [
    {'companyName': 'pw skills',
     'product': 'Affordable AI',
     'courseOffered': 'Machine Learning with Deployment'},
    
    {'companyName': 'pw skills',
     'product': 'Affordable AI',
     'courseOffered': 'Deep Learning for NLP and Computer vision'},
    
    {'companyName': 'pw skills',
     'product': 'Master Program',
     'courseOffered': 'Data Science Masters Program'}
]

# %%
coll_create.insert_many(data4)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('69665d0e3ed2332a724e8b61'), 'name': 'Taher', 'class': 'Dataanalyst stud', 'timing': 'flexi'}
# {'_id': ObjectId('69665fb73ed2332a724e8b63'), 'name': 'Taher', 'class': 'Dataanalyst stud', 'timing': 'flexi'}
# {'_id': ObjectId('6966602d3ed2332a724e8b64'), 'list_course': ['data analytisc', 'java', 'python'], 'mentor': ['Rajiv', 'Imran', 'Ajay']}
# {'_id': ObjectId('6966624e3ed2332a724e8b65'), 'name': 'Amy', 'address': 'Apple st 652'}
# {'_id': ObjectId('6966624e3ed2332a724e8b66'), 'name': 'Hannah', 'address': 'Mountain 21'}
# {'_id': ObjectId('6966624e3ed2332a724e8b67'), 'name': 'Michael', 'address': 'Valley 345'}
# {'_id': ObjectId('6966624e3ed2332a724e8b68'), 'name': 'Sandy', 'address': 'Ocean blvd 2'}
# {'_id': ObjectId('6966624e3ed2332a724e8b69'), 'name': 'Betty', 'address': 'Green Grass 1'}
# {'_id': ObjectId('6966624e3ed2332a724e8b6a'), 'name': 'Richard', 'address': 'Sky st 331'}
# ...

# %%
data5 = [
    {'_id': '3', 'companyName': 'pw skills', 'Faculty': 'XYZ'},
    {'_id': '4', 'companyName': 'pw skills', 'Faculty': 'ABC'},
    {'_id': '5', 'companyName': 'pw skills', 'Faculty': 'PQR'},
]

# %%
coll_create.insert_many(data5)

# %%
coll_create.find_one()
# Out:
# {'_id': ObjectId('69665d0e3ed2332a724e8b61'),
#  'name': 'Taher',
#  'class': 'Dataanalyst stud',
#  'timing': 'flexi'}

# %%
for i in coll_create.find({'companyName':'pw skills'}):
    print(i)
# Out:
# {'_id': ObjectId('6966651a3ed2332a724e8b71'), 'companyName': 'pw skills', 'product': 'Affordable AI', 'courseOffered': 'Machine Learning with Deployment'}
# {'_id': ObjectId('6966651a3ed2332a724e8b72'), 'companyName': 'pw skills', 'product': 'Affordable AI', 'courseOffered': 'Deep Learning for NLP and Computer vision'}
# {'_id': ObjectId('6966651a3ed2332a724e8b73'), 'companyName': 'pw skills', 'product': 'Master Program', 'courseOffered': 'Data Science Masters Program'}
# {'_id': '3', 'companyName': 'pw skills', 'Faculty': 'XYZ'}
# {'_id': '4', 'companyName': 'pw skills', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'pw skills', 'Faculty': 'PQR'}

# %%
for i in coll_create.find({'_id':{'$gte':'4'}}):
    print(i)
# Out:
# {'_id': '4', 'companyName': 'pw skills', 'Faculty': 'ABC'}
# {'_id': '5', 'companyName': 'pw skills', 'Faculty': 'PQR'}

# %%
coll_create.update_many({'companyName':"pw skills"},{"$set":{'companyName':"pw"}})
