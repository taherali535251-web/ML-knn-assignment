# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
x,y = make_classification(n_samples=1000, n_features=20,n_classes=2,random_state=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=1)

# %%
adaboost = AdaBoostClassifier()
adaboost.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
y_pred = adaboost.predict(x_test)

#evaluate model
print("current model performance")
print(f"accuracy:{accuracy_score(y_test,y_pred)}")
print(f"classification report:{classification_report(y_test,y_pred)}")
print(f"confusion_matrix:{confusion_matrix(y_test,y_pred)}")
# Out:
# current model performance
# accuracy:0.8533333333333334
# classification report:              precision    recall  f1-score   support
#
#            0       0.83      0.86      0.84       139
#            1       0.87      0.85      0.86       161
#
#     accuracy                           0.85       300
#    macro avg       0.85      0.85      0.85       300
# weighted avg       0.85      0.85      0.85       300
#
# confusion_matrix:[[119  20]
#  [ 24 137]]

# %%
#hyperparametrer tuning
from sklearn.model_selection import GridSearchCV
param = {
    'n_estimators':[50, 100, 200],
    'learning_rate':[0.01, 0.1, 1.0, 1.5, 2.0],
    'algorithm':['SAMME','SAMME.R']
}

# %%
ada = AdaBoostClassifier()
grid = GridSearchCV(estimator=ada,param_grid=param,cv=5,verbose=3,n_jobs=-1)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# c:\Users\TAHERALI\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 75 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 75 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\TAHERALI\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\TAHERALI\anaconda3\Lib\site-packages\sklearn\base.py", line 1382, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# ...

# %%
grid.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.1, 'n_estimators': 200}

# %%
grid.best_score_
# Out:
# np.float64(0.8585714285714285)

# %%
best_model = grid.best_estimator_

# %%
y1_pred =best_model.predict(x_test)

# %%
print("current model performance")
print(f"accuracy:{accuracy_score(y_test,y1_pred)}")
print(f"classification report:{classification_report(y_test,y1_pred)}")
print(f"confusion_matrix:{confusion_matrix(y_test,y1_pred)}")
# Out:
# current model performance
# accuracy:0.8566666666666667
# classification report:              precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       139
#            1       0.88      0.85      0.86       161
#
#     accuracy                           0.86       300
#    macro avg       0.86      0.86      0.86       300
# weighted avg       0.86      0.86      0.86       300
#
# confusion_matrix:[[120  19]
#  [ 24 137]]

# %%
#adaboostv regresssor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
x,y = make_regression(n_samples=1000,n_features=2,noise=10,random_state=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=1)

# %%
adareg = AdaBoostRegressor()
adareg.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred = adareg.predict(x_test)
#evaluation the model
print("cutrrent model performance")
print(f"R2 score:{r2_score(y_test,y_pred)}")
print(f"MEAN ABSOLUTE ERROR:{mean_absolute_error(y_test,y_pred)}")
print(f"MEAN Squared error:{mean_squared_error(y_test,y_pred)}")
# Out:
# cutrrent model performance
# R2 score:0.9532397049896699
# MEAN ABSOLUTE ERROR:14.732148051990334
# MEAN Squared error:386.496116503675

# %%
#hyperparameter tuning
from sklearn.model_selection import GridSearchCV
param = {
    'n_estimators':[50, 100, 200],
    'learning_rate':[0.01, 0.1, 0.5, 1.0, 1.5],
    'loss':['linear','square','exponential']
}

# %%
grid1 = GridSearchCV(estimator=adareg,param_grid=param,cv=5,verbose=3)

# %%
grid1.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV 1/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.933 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.933 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.949 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.930 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.935 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.939 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.935 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.955 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.933 total time=   0.1s
# ...

# %%
grid1.best_params_
# Out:
# {'learning_rate': 1.5, 'loss': 'square', 'n_estimators': 200}

# %%
best_model =grid1.best_estimator_
y_pred = best_model.predict(x_test)

#evaluation the model
print("cutrrent model performance")
print(f"R2 score:{r2_score(y_test,y_pred)}")
print(f"MEAN ABSOLUTE ERROR:{mean_absolute_error(y_test,y_pred)}")
print(f"MEAN Squared error:{mean_squared_error(y_test,y_pred)}")
# Out:
# cutrrent model performance
# R2 score:0.9624807606915491
# MEAN ABSOLUTE ERROR:13.178480593018094
# MEAN Squared error:310.1143883648469
