# %%
class Student:
    def __init__(self,name,price):
        self.__name = name
        self.__price = price

    @property
    def access__price(self):
        return self.__price

# %%
a = Student("taher",200)

# %%
a.access__price
# Out:
# 200

# %%
class Student:
    def __init__(self,name,price):
        self.name = name
        self.price = price

# %%
b = Student("Taher",3000)

# %%
b.name
# Out:
# 'Taher'

# %%
b.price
# Out:
# 3000
